# %%
# ! pip install ultralytics==8.0.196
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.1/631.1 KB 1.7 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 KB 1.7 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="sK7KyNXL8rhhfnM3B78q")
project = rf.workspace("face-detection-xnlic").project("face-region-detect")
dataset = project.version(2).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to face-region-detect-2 in yolov8:: 100%|██████████| 2389/2389 [00:00<00:00, 12885.59it/s]

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4090, 24217MiB)
# Setup complete ✅ (16 CPUs, 31.1 GB RAM, 173.6/468.4 GB disk)

# %%
# %reload_ext tensorboard

# %%
#@title Select YOLOv8 🚀 logger {run: 'auto'}
# %load_ext tensorboard
# %tensorboard --logdir ./face_region_yolo
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-e3e70682c2094cac" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e3e70682c2094cac");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')  # build a new model from scratch
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data='data2.yaml', epochs=300)# train the model)
results = model.val()  # evaluate model performance on the validation set
 # export the model to ONNX format
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
results = model('/home/kiru/snak/face-detection-2/valid/360_F_366254744_aRYpqyZN2wFbSI8jZ4WATa13st9MF9Zf_jpg.rf.0ca46939c0635f74c62e5dd4cd390604.jpg')  # predict on an image
results = model.export(format='onnx')
# Out:
# image 1/1 /home/kiru/snak/face-detection-2/valid/360_F_366254744_aRYpqyZN2wFbSI8jZ4WATa13st9MF9Zf_jpg.rf.0ca46939c0635f74c62e5dd4cd390604.jpg: 224x640 1 Forehead, 1 Left-eye, 139.1ms
# Speed: 8.7ms preprocess, 139.1ms inference, 1.7ms postprocess per image at shape (1, 3, 224, 640)
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (13th Gen Intel Core(TM) i5-13400)
#
# PyTorch: starting from 'runs/detect/train4/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 13, 8400) (6.0 MB)
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ONNX: export success ✅ 15.2s, saved as 'runs/detect/train4/weights/best.onnx' (11.7 MB)
#
# Export complete (35.5s)
# Results saved to /home/kiru/snak/runs/detect/train4/weights
# Predict:         yolo predict task=detect model=runs/detect/train4/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train4/weights/best.onnx imgsz=640 data=data.yaml
# ...

# %%
# results = model.predict('/home/kiru/snak/face-detection-2/valid/360_F_366254744_aRYpqyZN2wFbSI8jZ4WATa13st9MF9Zf_jpg.rf.0ca46939c0635f74c62e5dd4cd390604.jpg')
# import matplotlib.pyplot as plt
# import cv2
# plots = results[0].plot()

# boxes = results[0].boxes

# for box in boxes :
#     print(box.xyxy.cpu().detach().numpy().tolist())
#     print(box.conf.cpu().detach().numpy().tolist())
#     print(box.cls.cpu().detach().numpy().tolist())
# Out:
# image 1/1 /home/kiru/snak/face-detection-2/valid/360_F_366254744_aRYpqyZN2wFbSI8jZ4WATa13st9MF9Zf_jpg.rf.0ca46939c0635f74c62e5dd4cd390604.jpg: 224x640 1 Forehead, 1 Left-eye, 4.1ms
# Speed: 1.3ms preprocess, 4.1ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 640)
# [[650.0264892578125, 8.498857498168945, 780.5216064453125, 96.05401611328125]]
# [0.533935010433197]
# [2.0]
# [[643.296875, 88.56307983398438, 800.66943359375, 144.83740234375]]
# [0.5206550359725952]
# [4.0]

# %%
# plot_bboxes(image, results[0].boxes.data, score=False)

# %%
ls
# Out:
#  bus.jpg
#  datasets/
#  data.yaml
# 'Detr_finetuning copy.ipynb'
#  Detr_finetuning.ipynb
#  face_check/
#  face_check.zip
#  face-detection-1/
#  face-detection-2/
#  face-regions-detection-2/
# 'Fine_tuning_YOLOS_for_object_detection_on_custom_dataset_(balloon).ipynb'
#  h_trainer_detr.ipynb
#  lightning_logs/
#  runs/
#  yolov8n.pt

# %%
# !yolo task=detect mode=predict model=/home/kiru/snak/runs/detect/train4/weights/best.pt conf=0.25 source='2.jpg'
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (13th Gen Intel Core(TM) i5-13400)
# Model summary (fused): 168 layers, 3007403 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /home/kiru/snak/2.jpg: 512x640 1 Between-eyebrows, 1 Chin, 2 Foreheads, 2 Left-cheeks, 2 Left-eyes, 1 Mouth, 1 Nose, 1 Right-cheek, 1 Right-eye, 9409.1ms
# Speed: 41.8ms preprocess, 9409.1ms inference, 67.2ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# results

# %%
import cv2
from PIL import Image
k = Image.open('2.jpg')
results = model.predict(k)
# Out:
# 0: 512x640 1 Between-eyebrows, 1 Chin, 2 Foreheads, 2 Left-cheeks, 2 Left-eyes, 1 Mouth, 1 Nose, 1 Right-cheek, 1 Right-eye, 128.5ms
# Speed: 10.1ms preprocess, 128.5ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 640)
